# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
from pathlib import Path
from tqdm import tqdm
import os

# %% [markdown]
# TODO:
# <!-- - Table with metrics summary (mean + std) -->
# - Create full plot (with multiple subplots)
# - Possibly: assert to check ass exp uses same dsets

# %%
# Make sure the path is correct, i.e. change according which experiment we want
# root_path = Path('results_atari')
root_path = Path('results')

experiments = sorted([path.stem for path in root_path.iterdir()])
exp_box = [widgets.Checkbox(value=False, description=label, layout=widgets.Layout(width='600px')) for label in experiments]
exp_vbox = widgets.VBox(exp_box)
display(exp_vbox)
# Out:
# VBox(children=(Checkbox(value=False, description='20230501_fake_train_bus_6', layout=Layout(width='600px')), C…

# %%
# OUTPUT_FOLDER = root_path / 'paper_0517_typhon_3'
OUTPUT_FOLDER = root_path / 'paper_0517_baseline_temp'
assert not os.path.exists(OUTPUT_FOLDER), 'OUTPUT FOLDER ALREADY EXISTS! Delete it or change name'
os.mkdir(OUTPUT_FOLDER)

# %%
# Load data
metrics_paths = []
for checkbox in exp_box:
    if checkbox.value == True:
        metrics_paths.append((checkbox.description, root_path / checkbox.description / 'run_plot' / 'metrics.csv'))

# Get only exp names
exps_names = [n for n, _ in metrics_paths]

# load dfs and put in a dict with exp name as key
dfs = {name: pd.read_csv(mpath) for name, mpath in metrics_paths}

# %%
metrics_plot = dfs[exps_names[0]]
datasets_checkboxes = [widgets.Checkbox(value=True, description=label) for label in pd.unique(metrics_plot['dataset'])]
datasets_vbox = widgets.VBox(children=datasets_checkboxes)
 
metrics_checkboxes = [widgets.Checkbox(value=True, description=label) for label in pd.unique(metrics_plot['metric'])]
metrics_vbox = widgets.VBox(children=metrics_checkboxes)

split_checkboxes = [widgets.Checkbox(value=True, description=label) for label in ['train', 'validation', 'test']]
split_vbox = widgets.VBox(split_checkboxes)


vboxes = [datasets_vbox, metrics_vbox, split_vbox]
output = widgets.HBox(children=vboxes)
display(output)
# Out:
# HBox(children=(VBox(children=(Checkbox(value=True, description='BUS_VAL_RESHUFFLED'),)), VBox(children=(Checkb…

# %%
# Get selected dsets
dsets = [d.description for d in datasets_checkboxes if d.value == True]
# Get selected metrics
metrics = [m.description for m in metrics_checkboxes if m.value == True]
# Get selected splits (train, validation, test)
splits = [c.description for c in split_checkboxes if c.value == True]


# TODO: loop


values = pd.DataFrame()
vs = []
# Loop over dsets
for dset_name in dsets:
    # Loop over metrics
    for metric_name in metrics:
        # Loop over type (train, validation, test)
        for split in splits:
            # Loop over dset
            for exp in exps_names:
                # Get dataframe
                df = dfs[exp]
                # Filted dset
                df = df[df['dataset'] == dset_name]
                # Filter metrics
                df = df[df['metric'] == metric_name]
                # Select split
                df_split = df[df['split'] == split]
                # Remove -1, only for test split actually
                df_split = df_split[df_split['epoch'] != -1]
                # Create column name
                col_name = f"{exp}_{dset_name}_{metric_name}_{split}"
                # Insert in df with new index
                vs.append(df_split['value'].set_axis(df_split['epoch'], axis=0).rename(col_name))
#                 values.insert(0, col_name, df_split['value'].set_axis(df_split['epoch'])) # works also
# Merge into a single df
values = pd.concat(vs, axis=1)
values
# Out:
#        20230513_baseline_bus_reshuffled_5_BUS_VAL_RESHUFFLED_loss_train  \
# epoch
# 0                                               0.886462
# 62                                              0.833880
# 124                                             0.835878
# 186                                             0.832705
# 248                                             0.838778
# ...                                                  ...
# 5952                                            0.832532
# 6014                                            0.834549
# 6076                                            0.826783
# 6138                                            0.817722
# 6200                                            0.832484
#
#        20230514_baseline_bus_5_BUS_VAL_RESHUFFLED_loss_train  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_6_BUS_VAL_RESHUFFLED_loss_train  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_7_BUS_VAL_RESHUFFLED_loss_train  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_8_BUS_VAL_RESHUFFLED_loss_train  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230513_baseline_bus_reshuffled_5_BUS_VAL_RESHUFFLED_loss_validation  \
# epoch
# 0                                               0.770391
# 62                                              0.684914
# 124                                             0.683359
# 186                                             0.671770
# 248                                             0.682216
# ...                                                  ...
# 5952                                            0.696638
# 6014                                            0.688813
# 6076                                            0.688891
# 6138                                            0.687014
# 6200                                            0.690054
#
#        20230514_baseline_bus_5_BUS_VAL_RESHUFFLED_loss_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_6_BUS_VAL_RESHUFFLED_loss_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_7_BUS_VAL_RESHUFFLED_loss_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_8_BUS_VAL_RESHUFFLED_loss_validation  ...  \
# epoch                                                              ...
# 0                                                    NaN           ...
# 62                                                   NaN           ...
# 124                                                  NaN           ...
# 186                                                  NaN           ...
# 248                                                  NaN           ...
# ...                                                  ...           ...
# 5952                                                 NaN           ...
# 6014                                                 NaN           ...
# 6076                                                 NaN           ...
# 6138                                                 NaN           ...
# 6200                                                 NaN           ...
#
#        20230513_baseline_bus_reshuffled_5_BUS_VAL_RESHUFFLED_hd_validation  \
# epoch
# 0                                             408.134838
# 62                                            102.118126
# 124                                           107.069052
# 186                                            90.321297
# 248                                           101.402090
# ...                                                  ...
# 5952                                          129.120569
# 6014                                           95.368999
# 6076                                           80.878269
# 6138                                           79.545736
# 6200                                          118.358983
#
#        20230514_baseline_bus_5_BUS_VAL_RESHUFFLED_hd_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_6_BUS_VAL_RESHUFFLED_hd_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_7_BUS_VAL_RESHUFFLED_hd_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_8_BUS_VAL_RESHUFFLED_hd_validation  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230513_baseline_bus_reshuffled_5_BUS_VAL_RESHUFFLED_hd_test  \
# epoch
# 0                                             399.586334
# 62                                             57.424429
# 124                                            68.852480
# 186                                            97.332946
# 248                                            62.044623
# ...                                                  ...
# 5952                                           59.141904
# 6014                                           38.524958
# 6076                                           58.881168
# 6138                                           43.183990
# 6200                                           44.929307
#
#        20230514_baseline_bus_5_BUS_VAL_RESHUFFLED_hd_test  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_6_BUS_VAL_RESHUFFLED_hd_test  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_7_BUS_VAL_RESHUFFLED_hd_test  \
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
#        20230514_baseline_bus_8_BUS_VAL_RESHUFFLED_hd_test
# epoch
# 0                                                    NaN
# 62                                                   NaN
# 124                                                  NaN
# 186                                                  NaN
# 248                                                  NaN
# ...                                                  ...
# 5952                                                 NaN
# 6014                                                 NaN
# 6076                                                 NaN
# 6138                                                 NaN
# 6200                                                 NaN
#
# [101 rows x 135 columns]

# %%
def pretty_dset_name(name):
    if name == "BUS_SELECTED":
        return "UDIAT"
    else:
        return name
    
pretty_print = {
    'auc': 'AUC',
    'loss': 'Loss',
    'accuracy': 'Accuracy',
    'precision': 'Precision',
    'recall': 'Recall',
    'f1score': 'F1 Score',
    'specificity': 'Specificity',
    'trained': 'Training',
    'specialized': 'Specialization',
    'iou': 'IoU',
    'dice': 'Dice Score',
    'hd': 'HD'
}

# %%
MIN_EPOCH = 0
MAX_EPOCH = 1000
df = values.loc[MIN_EPOCH:]
df = values.loc[:MAX_EPOCH]

linewidth = 8

confidence_alpha = 0.4

plot_title = False

fontsizes = {
    'legend': 50,
    'axis': 60,
    'ticks': 50,
    'title': 70
}

yl = {
#     'loss': (0.65, 1.04),
    'recall': (0, 1),
    'iou': (0, 1),
    'f1': (0, 1)
}

lloc = {
    'loss': 'upper right'
}

# xtk = [20000, 40000, 60000, 80000, 100000]
# xtk_lab = ['20', '40', '60', '80', '100']
xtk = [1000, 2000, 3000, 4000, 5000, 6000]
xtk_lab = ['1', '2', '3', '4', '5', '6']

for dset_name in dsets:
    for metric_name in metrics:
        # Create new image
        fig, ax = plt.subplots(figsize=(16, 9))

        for split in splits:
            cols = [f"{exp}_{dset_name}_{metric_name}_{split}" for exp in exps_names]
            x = df[cols].index
            mean_val = df[cols].mean(axis=1)
            std_val = df[cols].std(axis=1)
            ax.plot(x, mean_val, label=split, linewidth=linewidth)
            ax.fill_between(x, mean_val + std_val, mean_val - std_val, alpha=confidence_alpha)

        
        ax.set_xlabel('Epochs (x 1\'000)', fontsize=fontsizes['axis'])
        ax.set_ylabel(pretty_print[metric_name], fontsize=fontsizes['axis'])
        if metric_name in yl: ax.set_ylim(yl[metric_name])
        title = f"{pretty_dset_name(dset_name)}_{metric_name}"
        if plot_title: plt.title(f"{pretty_dset_name(dset_name)}, {pretty_print[metric_name]}", size=fontsizes['title'])
        ymn, ymx = ax.get_ylim()
        if metric_name != 'hd':
            plt.yticks(np.arange(round(ymn, 1), ymx+0.01, 0.2), fontsize=fontsizes['ticks'])
        plt.xticks(xtk, fontsize=fontsizes['ticks'])
        ax.set_xticklabels(xtk_lab)
        ax.set_ylim([0.74, 1])
#         plt.legend(loc=lloc.get(metric_name, 'lower right'), fontsize=fontsizes['legend'])
        fig.tight_layout()
        plt.savefig(OUTPUT_FOLDER / f"{title}.pdf")
        plt.show()

# %%
dset_name = 'BUS_SELECTED'
split = 'validation'

for metric_name in metrics:
    cols = [f"{exp}_{dset_name}_{metric_name}_{split}" for exp in exps_names]
    mean_val = df[cols].mean(axis=1)
    if metric_name == 'loss':
        print(f'{metric_name} min found at {np.argmin(mean_val)}: {np.min(mean_val)}')
    else:
        print(f'{metric_name} max found at {np.argmax(mean_val)}: {np.max(mean_val)}')
# Out:
# loss min found at 72: 0.6772323383225336
# accuracy max found at 31: 0.9677075168542695
# precision max found at 88: 0.9386609907196414
# recall max found at 0: 0.9247116875862119
# f1score max found at 31: 0.7716519305714994
# specificity max found at 88: 0.9965750955604616
# iou max found at 31: 0.6283787907704007
# dice max found at 31: 0.7716519306039314
# hd max found at 0: 399.647468262782

# %%
print('31 --> 31\'000 epochs')
# Out:
# 31 --> 31'000 epochs
